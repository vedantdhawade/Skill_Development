# %% [raw]
# Matplotlib

# %%
import matplotlib.pyplot as plt

# %%
x = ["Python","C++","Java"]
y = [12,34,24]
plt.xlabel("Languages")
plt.ylabel("Popularity")
plt.title("Popularity")
color = ["r","b","g"]
plt.bar(x,y,width = 0.4,color=color,label="Popularity")
plt.legend()
plt.show()
