# %%
import numpy as np
import seaborn as sns

# %%
iris = sns.load_dataset("iris")

# %%
iris.head(10)
iris.shape
# Out:
# (150, 5)

# %%
iris.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
iris.isnull().count()
# Out:
# sepal_length    150
# sepal_width     150
# petal_length    150
# petal_width     150
# species         150
# dtype: int64

# %%
iris[iris["species"] == "setosa"]
# Out:
#     sepal_length  sepal_width  petal_length  petal_width species
# 0            5.1          3.5           1.4          0.2  setosa
# 1            4.9          3.0           1.4          0.2  setosa
# 2            4.7          3.2           1.3          0.2  setosa
# 3            4.6          3.1           1.5          0.2  setosa
# 4            5.0          3.6           1.4          0.2  setosa
# 5            5.4          3.9           1.7          0.4  setosa
# 6            4.6          3.4           1.4          0.3  setosa
# 7            5.0          3.4           1.5          0.2  setosa
# 8            4.4          2.9           1.4          0.2  setosa
# 9            4.9          3.1           1.5          0.1  setosa
# 10           5.4          3.7           1.5          0.2  setosa
# 11           4.8          3.4           1.6          0.2  setosa
# 12           4.8          3.0           1.4          0.1  setosa
# ...

# %%
iris[iris["petal_length"] > 5].sort_values("petal_length").tail()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 131           7.9          3.8           6.4          2.0  virginica
# 105           7.6          3.0           6.6          2.1  virginica
# 117           7.7          3.8           6.7          2.2  virginica
# 122           7.7          2.8           6.7          2.0  virginica
# 118           7.7          2.6           6.9          2.3  virginica

# %%
iris2 = iris[["sepal_length","sepal_width","species"]]

# %%
iris2
# Out:
#      sepal_length  sepal_width    species
# 0             5.1          3.5     setosa
# 1             4.9          3.0     setosa
# 2             4.7          3.2     setosa
# 3             4.6          3.1     setosa
# 4             5.0          3.6     setosa
# ..            ...          ...        ...
# 145           6.7          3.0  virginica
# 146           6.3          2.5  virginica
# 147           6.5          3.0  virginica
# 148           6.2          3.4  virginica
# 149           5.9          3.0  virginica
#
# [150 rows x 3 columns]

# %%
iris3 = iris2.groupby("species").median()

# %%
iris3
# Out:
#             sepal_length  sepal_width
# species
# setosa               5.0          3.4
# versicolor           5.9          2.8
# virginica            6.5          3.0

# %%
iris2["Petal_Area"] = iris2["sepal_length"] * iris2["sepal_width"]
# Out:
# /tmp/ipykernel_4983/2954473654.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iris2["Petal_Area"] = iris2["sepal_length"] * iris2["sepal_width"]

# %%
iris2
# Out:
#      sepal_length  sepal_width    species  Petal_Area
# 0             5.1          3.5     setosa       17.85
# 1             4.9          3.0     setosa       14.70
# 2             4.7          3.2     setosa       15.04
# 3             4.6          3.1     setosa       14.26
# 4             5.0          3.6     setosa       18.00
# ..            ...          ...        ...         ...
# 145           6.7          3.0  virginica       20.10
# 146           6.3          2.5  virginica       15.75
# 147           6.5          3.0  virginica       19.50
# 148           6.2          3.4  virginica       21.08
# 149           5.9          3.0  virginica       17.70
#
# [150 rows x 4 columns]

# %%
x = iris2.groupby("species").mean()
x
# Out:
#             sepal_length  sepal_width  Petal_Area
# species
# setosa             5.006        3.428     17.2578
# versicolor         5.936        2.770     16.5262
# virginica          6.588        2.974     19.6846

# %%
largest_petal_area_species = x.idxmax()
largest_petal_area_species
# Out:
# sepal_length    virginica
# sepal_width        setosa
# Petal_Area      virginica
# dtype: object

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.boxplot(x="species", y="sepal_length", data=iris)
plt.title("Sepal Length by Species")
plt.show()

sns.scatterplot(x="petal_length", y="petal_width", hue="species", data=iris)
plt.title("Petal Length vs. Petal Width")
plt.show()

# %%
iris2
# Out:
#      sepal_length  sepal_width    species  Petal_Area
# 0             5.1          3.5     setosa       17.85
# 1             4.9          3.0     setosa       14.70
# 2             4.7          3.2     setosa       15.04
# 3             4.6          3.1     setosa       14.26
# 4             5.0          3.6     setosa       18.00
# ..            ...          ...        ...         ...
# 145           6.7          3.0  virginica       20.10
# 146           6.3          2.5  virginica       15.75
# 147           6.5          3.0  virginica       19.50
# 148           6.2          3.4  virginica       21.08
# 149           5.9          3.0  virginica       17.70
#
# [150 rows x 4 columns]

# %%
print("Species with largest average sepal_length:", x["sepal_length"].idxmax())
print("Species with smallest average petal_width:", x["petal_width"].idxmin())

print("Flowers with sepal_length > 6:", iris[iris["sepal_length"] > 6].shape[0])
# Out:
# Species with largest average sepal_length: virginica
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/Desktop/Jupiter/myenv/lib/python3.12/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'petal_width'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[46], line 2
# ...
